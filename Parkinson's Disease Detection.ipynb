# %% [markdown]
# <a href="https://colab.research.google.com/github/shyamaldeepak/devsage/blob/master/Parkinson's%20Disease%20Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
parkinsons_data = pd.read_csv('/content/pd_speech_features (1).csv')

# %%
parkinsons_data.head()
# Out:
#    id  gender  ...  tqwt_kurtosisValue_dec_36  class
# 0   0       1  ...                    18.9405      1
# 1   0       1  ...                    45.1780      1
# 2   0       1  ...                     4.7666      1
# 3   1       0  ...                     4.0603      1
# 4   1       0  ...                     6.1164      1
#
# [5 rows x 755 columns]

# %%
parkinsons_data.shape
# Out:
# (756, 755)

# %%
parkinsons_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Columns: 755 entries, id to class
# dtypes: float64(749), int64(6)
# memory usage: 4.4 MB

# %%
parkinsons_data.isnull().sum()
# Out:
# id                           0
# gender                       0
# PPE                          0
# DFA                          0
# RPDE                         0
#                             ..
# tqwt_kurtosisValue_dec_33    0
# tqwt_kurtosisValue_dec_34    0
# tqwt_kurtosisValue_dec_35    0
# tqwt_kurtosisValue_dec_36    0
# class                        0
# Length: 755, dtype: int64

# %%
# getting some statistical measures about the data
parkinsons_data.describe()
# Out:
#                id      gender  ...  tqwt_kurtosisValue_dec_36       class
# count  756.000000  756.000000  ...                 756.000000  756.000000
# mean   125.500000    0.515873  ...                  31.481110    0.746032
# std     72.793721    0.500079  ...                  34.230991    0.435568
# min      0.000000    0.000000  ...                   2.364000    0.000000
# 25%     62.750000    0.000000  ...                   3.948750    0.000000
# 50%    125.500000    1.000000  ...                  10.637250    1.000000
# 75%    188.250000    1.000000  ...                  61.125325    1.000000
# max    251.000000    1.000000  ...                 156.423700    1.000000
#
# [8 rows x 755 columns]

# %%
# distribution of target Variable 
parkinsons_data['GNE_mean'].value_counts()
# Out:
# 1.08210    2
# 1.08130    2
# 1.02210    2
# 1.18830    2
# 1.06700    2
#           ..
# 0.96170    1
# 0.99108    1
# 0.81318    1
# 1.27590    1
# 1.18750    1
# Name: GNE_mean, Length: 743, dtype: int64

# %%
parkinsons_data.groupby('GNE_mean').mean()
# Out:
#              id  gender  ...  tqwt_kurtosisValue_dec_36  class
# GNE_mean                 ...
# 0.62655   157.0     1.0  ...                    14.9227    0.0
# 0.62978   146.0     1.0  ...                     3.2140    1.0
# 0.63392   157.0     1.0  ...                    52.2294    0.0
# 0.67183    96.0     1.0  ...                     3.2975    0.0
# 0.67481    80.0     0.0  ...                     2.7635    1.0
# ...         ...     ...  ...                        ...    ...
# 2.73590    41.0     0.0  ...                     3.6258    0.0
# 2.77110    48.0     1.0  ...                    16.9370    0.0
# 2.80770   178.0     0.0  ...                     4.1641    0.0
# 4.60290    48.0     1.0  ...                    14.0581    0.0
# 4.95760    48.0     1.0  ...                     7.5574    0.0
#
# [743 rows x 754 columns]

# %%
X = parkinsons_data.drop(columns=['id','GNE_mean'], axis=1)
Y = parkinsons_data['GNE_mean']

# %%
print(X)
# Out:
#      gender      PPE  ...  tqwt_kurtosisValue_dec_36  class
# 0         1  0.85247  ...                    18.9405      1
# 1         1  0.76686  ...                    45.1780      1
# 2         1  0.85083  ...                     4.7666      1
# 3         0  0.41121  ...                     4.0603      1
# 4         0  0.32790  ...                     6.1164      1
# ..      ...      ...  ...                        ...    ...
# 751       0  0.80903  ...                     6.8671      0
# 752       0  0.16084  ...                    28.4170      0
# 753       0  0.88389  ...                     5.0424      0
# 754       0  0.83782  ...                     3.7131      0
# 755       0  0.81304  ...                     3.1527      0
#
# [756 rows x 753 columns]

# %%
print(Y)
# Out:
# 0      1.17300
# 1      1.02210
# 2      0.84951
# 3      0.83405
# 4      0.83556
#         ...
# 751    1.17130
# 752    1.19440
# 753    0.97851
# 754    0.87012
# 755    0.81328
# Name: GNE_mean, Length: 756, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (756, 753) (604, 753) (152, 753)

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train = scaler.transform(X_train)

X_test = scaler.transform(X_test)

# %%
print(X_train)
# Out:
# [[ 0.99669421  0.3484459   1.94836243 ...  0.08898025  1.31564894
#    0.58499763]
#  [-1.00331676  0.59741695 -0.07079278 ... -0.30682153  0.78639303
#    0.58499763]
#  [-1.00331676 -2.04139106 -1.54292361 ...  0.06506809 -0.70808211
#   -1.70940865]
#  ...
#  [ 0.99669421  0.44900144  0.01789488 ...  0.06847005  0.80891976
#    0.58499763]
#  [-1.00331676  0.60715013 -2.02276462 ...  2.15803582  1.6908753
#    0.58499763]
#  [ 0.99669421  0.23933508 -0.99856972 ...  1.20986453  1.22173395
#    0.58499763]]

# %%
print(Y_train)
# Out:
# 304    1.00390
# 178    1.19850
# 536    1.68150
# 698    1.15020
# 452    1.32590
#         ...
# 534    2.80770
# 584    1.45980
# 493    0.78195
# 527    1.52710
# 168    1.14990
# Name: GNE_mean, Length: 604, dtype: float64

# %%
model = svm.SVC(kernel='linear')

# %%
print(model)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
